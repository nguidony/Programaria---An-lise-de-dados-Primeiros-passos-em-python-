# %% [markdown]
# <a href="https://colab.research.google.com/github/nguidony/Programaria---Analise-de-dados-Primeiros-passos-em-python-/blob/main/analise_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd

# %%
dados=pd.read_excel('/content/drive/MyDrive/planilha_modulo3.xlsx')

# %%
dados.tail()#ultimos valores
dados.head()#primeiros valores
dados.shape #linhas colunas da tabela
len(dados) #tamanho
# Out:
# 4271

# %%
dados.columns #colunas
dados.info()#o q tem no dataset e os tipos de dados
dados.describe()#infos do dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# #Repetindo análise do excel - aula 2

# %%
#nome colunas
dados.columns
dados['GENERO'] #ver apenas os dados dessa coluna
# Out:
# 0       Masculino
# 1       Masculino
# 2       Masculino
# 3       Masculino
# 4        Feminino
#           ...
# 4266    Masculino
# 4267     Feminino
# 4268    Masculino
# 4269    Masculino
# 4270    Masculino
# Name: GENERO, Length: 4271, dtype: object

# %%
dados[dados['GENERO']=='Feminino'] #filtrando apenas mulheres == aquilo q a gente quer "igual a"| != tudo que diferente de
dados[dados['GENERO'].str.contains('não', na=False)] #na = false sem nulos
dados[dados['IDADE']>30]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96   39.0       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd   32.0       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi   53.0       50-54
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# ...          ...                               ...    ...         ...
# 4257        4257  043snvbsxn3fuyfe043j5comuyu8g6ba   46.0       45-49
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
# 4264        4264  028mfisr3mqazkn5n6swe028mt55nqzq   37.0       35-39
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# 1     Masculino          Parda  Não
# ...

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')] #combina 2 filtros
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg   46.0       45-49
# 5              5  zz0nlhbd8oxyiyxzz0nlh7g4xkiaza5v   32.0       30-34
# 7              7  zyc0twzno2sm5or5ovoxzyc0twz0300d   31.0       30-34
# 14            14  zwez49k0jhdvfkfst4zwef137uuf4ivy   35.0       35-39
# 23            23  zuqfcwtl9unfc5ezuqfcwm8coytsp5ap   46.0       45-49
# ...          ...                               ...    ...         ...
# 4214        4214  0gprow0ownrbfneftxf0gprow4kyrqdy   41.0       40-44
# 4221        4221  0fgi5bnb0u9b0fgc0jmqlbnvtu12b76d   34.0       30-34
# 4240        4240  0a5xgxb1ljmuqn0un8a10a5xg4eufs2l   37.0       35-39
# 4247        4247  07qzabp4ujpe4oz81udmb07qzabp4h0t   34.0       30-34
# 4251        4251  068hhicrqggu068huq0l2ab3g7liagy8   34.0       30-34
#
#         GENERO COR/RACA/ETNIA                   PCD  \
# 4     Feminino         Branca                   Não
# ...

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %%
dados[(dados['IDADE']<40) & (dados['COR/RACA/ETNIA']=='Amarela')]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 13            13  zwh83jpy6x40b95xigsr2zwh83jpflu3   24.0       22-24
# 85            85  zfeuk2m9jozahicujlla8zfeuk2g7apj   29.0       25-29
# 159          159  ytrnz3zyvn791t3dum1ytrnz3zp22tmk   37.0       35-39
# 170          170  yri3z491ejizlpj9ylu2k3jyri3z4915   34.0       30-34
# 195          195  yjbpxmkqz5yidh5oszyjbpxmkgcb1zd9   32.0       30-34
# ...          ...                               ...    ...         ...
# 3947        3947  2tnsh0gxdu3aq4z2d2tnsh0hk15brx7q   31.0       30-34
# 4058        4058  1t3ndwx8j50k0bz1t3ndwxdpwyg17c2k   27.0       25-29
# 4176        4176  0qpa64gqpieg60xpygnajt70qpa64g1a   27.0       25-29
# 4207        4207  0ibb8fj9qrwpswfqiil0ibb89e3e4hz3   30.0       30-34
# 4262        4262  02vlm03c29g3fcys8tj06102vlm0983h   31.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 13    Masculino        Amarela  Não
# 85     Feminino        Amarela  Não
# ...

# %%
df= pd.read_excel('/content/drive/MyDrive/lici.xlsx')
df
# Out:
#        Número Licitação  Código UG  \
# 0                 12016     160438
# 1                 12017     160203
# 2                 12017     193002
# 3                 12018     925135
# 4                 12018     110101
# ...                 ...        ...
# 15331         920182018     135023
# 15332         924192017     158274
# 15333         990922018     158139
# 15334         996252018     153035
# 15335         996252018     153035
#
#                                             Nome UG  Código Modalidade Compra  \
# 0         COMANDO 2 BRIGADA DE CAVALARIA MECANIZADA                       -99
# 1           2º BATALHAO DE ENGENHARIA DE CONSTRUCAO                         3
# 2      DEPARTAMENTO NACIONAL DE OBRAS CONT.AS SECAS                         2
# 3                  BANCO CENTRAL DO BRASIL - RECIFE                         6
# 4         GABINETE DA VICE-PRESIDENCIA DA REPUBLICA                         7
# ...

# %%
df[df['Situação Licitação']=='Encerrado'] # igual a
df['Situação Licitação'].value_counts()
# Out:
# Situação Licitação
# Encerrado                         9016
# Publicado                         3709
# Evento de Resultado de Julgame    1922
# Retificação                        127
# Evento de Alteração Publicad        93
# Evento de Suspensão Publicado       72
# Anulação                            67
# Revogação                           63
# Divulgado                           55
# Evento de Adiamento Publicado       46
# Evento de Retificação Public        45
# Evento de Revogação Publicad        40
# Evento de Alteração de Resul        37
# Evento de Anulação Publicado        18
# Evento de Retificação Divulg         7
# Inválido                             4
# Evento de Habilitação Public         4
# Evento de Alteração Divulgad         4
# Evento de Reabertura de Prazo        4
# Evento de Adiamento Divulgado        3
# Name: count, dtype: int64

# %%
dados.groupby('GENERO',dropna=False)['ID'].nunique() #valor por coluna genero numero de femino ou masc
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
dados['GENERO'].value_counts(dropna=False)
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      12
# NaN                        9
# Name: count, dtype: int64

# %%
dados[dados['IDADE']>30]['NIVEL'].value_counts()
# Out:
# NIVEL
# Sênior    525
# Pleno     408
# Júnior    274
# Name: count, dtype: int64

# %%
dados[(dados['IDADE']>30) & (dados['GENERO']=='Feminino')]['NIVEL'].value_counts()
# Out:
# NIVEL
# Pleno     117
# Sênior    114
# Júnior     96
# Name: count, dtype: int64

# %%
pd.pivot_table(dados, values=['ID'], index=['GENERO'], columns=['GESTOR?'], aggfunc='count')
# Out:
#                         ID
# GESTOR?                0.0  1.0
# GENERO
# Feminino               754  132
# Masculino             2212  578
# Prefiro não informar     9    2

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'NIVEL', 'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO'],
#       dtype='object')

# %% [markdown]
# # **Estatística - Módulo** **4**

# %%
import numpy as np

# %%
lista_idades = [26,30,32,22,26,35,40,20,43,31,23]

# %%
np.sum(lista_idades)
# Out:
# 328

# %%
len(lista_idades)
# Out:
# 11

# %%
np.sum(lista_idades)/len(lista_idades)
# Out:
# 29.818181818181817

# %%
media = np.mean(lista_idades)
print("Média aritmética=",media)
# Out:
# Média aritmética= 29.818181818181817

# %%
lista_idades.sort() #organiza por ordem crescente os números
lista_idades #olhando a lista conseguimos ver o valor do meio - que é 30, a nossa mediana
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43]

# %%
lista_idades=[26,30,32,22,26,35,40,20,43,31,23,100]
#adicionado o 100 para ver como a mediana vai ser calculado ja que sao dois valores no meio

# %%
lista_idades.sort()
lista_idades
# Out:
# [20, 22, 23, 26, 26, 30, 31, 32, 35, 40, 43, 100]

# %%
mediana= np.median(lista_idades)
print("Mediana=",mediana)
# Out:
# Mediana= 30.5

# %%
dados['IDADE'].mean()  #a mesma biblioteca pode ter mesma funções (agora é pandass)
# Out:
# 31.169168453657374

# %%
dados['IDADE'].median() #mediana por pandas
# Out:
# 30.0

# %%
dados['IDADE'].mode() #moda por pandas
# Out:
# 0    27.0
# Name: IDADE, dtype: float64

# %%
dados['IDADE'].std() #desvio padrão por pandas
# Out:
# 6.902802832143122

# %%
dados['IDADE'].min() #minimo por pandas
# Out:
# 18.0

# %%
dados['IDADE'].max() #maximo por pandas
# Out:
# 54.0

# %%
dados[dados['GENERO']=='Feminino']['IDADE'].mean() #média das idades dos membros genero feminino
#filtro e analise
# Out:
# 31.318051575931232

# %%
dados[dados['GENERO']=='Masculino']['IDADE'].mean()
# Out:
# 31.147876077930373

# %%
dados[dados['SALARIO'] == dados['SALARIO'].max()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 3016        3016  asb25r7i4trc5xnp0easb254h09r2oon   36.0       35-39
#
#          GENERO COR/RACA/ETNIA  PCD EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 3016  Masculino         Branca  Não                                  NaN
#
#      ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...               SETOR  \
# 3016                   NaN            True  ...  Internet/Ecommerce
#
#      NUMERO DE FUNCIONARIOS GESTOR?  CARGO COMO GESTOR         CARGO ATUAL  \
# 3016           de 101 a 500     0.0                NaN  Analytics Engineer
#
#        NIVEL          FAIXA SALARIAL  \
# 3016  Sênior  Acima de R$ 40.001/mês
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 3016                                      de 3 a 4 anos
#
#      QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?  \
# ...

# %%
dados[dados['SALARIO'] == dados['SALARIO'].min()]
# Out:
#      Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 961         961  s0pjhm8ly5lddu6qs0est2cr1u7vgq10   29.0       25-29
#
#        GENERO COR/RACA/ETNIA  PCD  \
# 961  Feminino        Amarela  Não
#
#                   EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 961  Sim, acredito que a minha a experiência profis...
#
#                                  ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  ...  \
# 961  Oportunidades de progressão de carreira, Quant...           False  ...
#
#                    SETOR NUMERO DE FUNCIONARIOS GESTOR?  \
# 961  Área de Consultoria               de 1 a 5     1.0
#
#                              CARGO COMO GESTOR CARGO ATUAL NIVEL  \
# 961  Sócio ou C-level (CEO, CDO, CIO, CTO etc)         NaN   NaN
#
#             FAIXA SALARIAL  \
# 961  Menos de R$ 1.000/mês
#
#     QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?  \
# 961                                      de 3 a 4 anos
#
# ...

# %% [markdown]
# #Valores faltantes

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4271 entries, 0 to 4270
# Data columns (total 28 columns):
#  #   Column                                                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                                                     --------------  -----
#  0   Unnamed: 0                                                                                                                 4271 non-null   int64
#  1   ID                                                                                                                         4271 non-null   object
#  2   IDADE                                                                                                                      4197 non-null   float64
# ...

# %% [markdown]
# #trabalhando a coluna de generos

# %%
dados.groupby('GENERO',dropna=False)['ID'].nunique()  #nunique valores unicos
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      12
# NaN                        9
# Name: ID, dtype: int64

# %%
# preencher os nulos
dados['GENERO']= dados['GENERO'].fillna('Prefiro não informar')

# %%
dados.groupby('GENERO',dropna=False)['ID'].nunique()  #nunique valores unicos
# Out:
# GENERO
# Feminino                1055
# Masculino               3194
# Prefiro não informar      21
# Name: ID, dtype: int64

# %% [markdown]
# #TRABALHANDO VALORES IDADE

# %%
dados['IDADE'].isnull().value_counts()
# Out:
# IDADE
# False    4197
# True       74
# Name: count, dtype: int64

# %%
dados[dados['IDADE'].isnull()]['FAIXA IDADE'].value_counts()
# Out:
# FAIXA IDADE
# 55+      68
# 17-21     6
# Name: count, dtype: int64

# %%
media_17_21= dados[dados['FAIXA IDADE']=='17-21']['IDADE'].mean()
 #colocar um valor medio para valores faltantes

# %%
dados.loc[(dados['FAIXA IDADE']=='17-21')& (dados['IDADE'].isnull()), 'IDADE']= media_17_21
#dados.loc é para localizar uma faixa de valores que tenha um interesse
#isnull é pra localizar esses nulos
# igual a media_17_21 é pra substituir os valores

# %%
dados[dados['FAIXA IDADE']=='55+']['IDADE']
#como ninguem preencheu a idade vamos usar a media geral
# Out:
# 9      NaN
# 66     NaN
# 96     NaN
# 121    NaN
# 156    NaN
#         ..
# 4001   NaN
# 4043   NaN
# 4048   NaN
# 4061   NaN
# 4215   NaN
# Name: IDADE, Length: 68, dtype: float64

# %%
dados[dados['FAIXA IDADE']=='55+']['NIVEL']
# Out:
# 9        Pleno
# 66      Júnior
# 96       Pleno
# 121      Pleno
# 156     Júnior
#          ...
# 4001       NaN
# 4043       NaN
# 4048       NaN
# 4061       NaN
# 4215    Sênior
# Name: NIVEL, Length: 68, dtype: object

# %%
media_geral= dados['IDADE'].mean()
media_geral
# Out:
# 31.153517220250375

# %%
dados.loc[(dados['FAIXA IDADE']=='55+')& (dados['IDADE'].isnull()),'IDADE'  ]= media_geral

# %% [markdown]
# ###Tratando coluna salário

# %%
dados[dados['SALARIO'].isnull()]
# Out:
#       Unnamed: 0                                ID  IDADE FAIXA IDADE  \
# 12            12  zwr9hqcpg513kaopenzwr9hibaqmldto   31.0       30-34
# 28            28  ztgepgj82o9oix0nztgepq2trcay6gpv   24.0       22-24
# 34            34  zsa9i6njd3e594mw0tvlk4zsa9iw86i9   24.0       22-24
# 39            39  zr4b2vm7dapp3linwqwn7zr4b2vmagqx   32.0       30-34
# 63            63  zm7o5yquakof0j6zm7vh3o0letznhdvh   26.0       25-29
# ...          ...                               ...    ...         ...
# 4242        4242  09oxwp6lsdwhw09ox1uobuxa8cq2pzma   26.0       25-29
# 4252        4252  064pe9b1htw7mflhif064pe95dotv6yf   39.0       35-39
# 4258        4258  03zjgijmnwv9qrlzbr03zjgij1eae1hw   25.0       25-29
# 4260        4260  03atvow8404tatt2iixjds03atvownkz   36.0       35-39
# 4261        4261  02xomoejng6c9152kde02xomww412qpg   33.0       30-34
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 12    Masculino         Branca  Não
# 28     Feminino          Parda  Não
# ...

# %%
dados[dados['SALARIO'].isnull()]['FAIXA SALARIAL'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
dados.loc[dados['SALARIO'].isnull(),'SALARIO']
# Out:
# 12     NaN
# 28     NaN
# 34     NaN
# 39     NaN
# 63     NaN
#         ..
# 4242   NaN
# 4252   NaN
# 4258   NaN
# 4260   NaN
# 4261   NaN
# Name: SALARIO, Length: 577, dtype: float64

# %%
mediana_salario= dados['SALARIO'].median()

# %%
dados.loc[dados['SALARIO'].isnull(),'SALARIO']=mediana_salario

# %% [markdown]
# ###Outliers

# %%
lista_idades=[26,30,32,22,26,35,400,20,43,31,23]
media=np.mean(lista_idades)

# %%
desvio=np.std(lista_idades)

# %%
media+3*desvio #limite superior
# Out:
# 383.2314444674207

# %%
media-3*desvio #limite inferior
# Out:
# -258.1405353765116

# %%
#quartil
import matplotlib.pyplot as plt

# %%
plt.boxplot(lista_idades)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78121e5d1690>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78121e5d1bd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78121e5d13c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x78121e5d2110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78121e5d23b0>],
#  'means': []}

# %%
plt.boxplot(dados['SALARIO'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x78121e187ac0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x78121e187d90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x78121e187820>],
#  'medians': [<matplotlib.lines.Line2D at 0x78121e1a4100>],
#  'fliers': [<matplotlib.lines.Line2D at 0x78121e1a5db0>],
#  'means': []}

# %%
Q1=dados['SALARIO'].quantile(0.25)
Q1
# Out:
# 4751.5

# %%
Q3=dados['SALARIO'].quantile(0.75)
Q3
# Out:
# 11794.5

# %%
IQR=Q3-Q1 #INTERQUARTIL
IQR
# Out:
# 7043.0

# %%
lim_superior=Q3+1.5*IQR
lim_superior
# Out:
# 22359.0

# %%
lim_inferior=Q1-1.5*IQR
lim_inferior
# Out:
# -5813.0

# %%
dados['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# de R$ 8.001/mês a R$ 12.000/mês     752
# de R$ 4.001/mês a R$ 6.000/mês      584
# de R$ 6.001/mês a R$ 8.000/mês      527
# de R$ 12.001/mês a R$ 16.000/mês    437
# de R$ 3.001/mês a R$ 4.000/mês      303
# de R$ 2.001/mês a R$ 3.000/mês      285
# de R$ 16.001/mês a R$ 20.000/mês    229
# de R$ 1.001/mês a R$ 2.000/mês      216
# de R$ 20.001/mês a R$ 25.000/mês    134
# de R$ 25.001/mês a R$ 30.000/mês     77
# de R$ 30.001/mês a R$ 40.000/mês     70
# Acima de R$ 40.001/mês               45
# Menos de R$ 1.000/mês                35
# Name: count, dtype: int64

# %%
media_salario=dados['SALARIO'].mean()
media_salario
# Out:
# 10517.53348162023

# %%
desvio_salario=dados['SALARIO'].std()
desvio_salario
# Out:
# 18096.21098911858

# %%
limite_superior=media_salario+3*desvio_salario
limite_superior
# Out:
# 64806.166448975964

# %%
dados[dados['SALARIO']>=limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês              19
# de R$ 30.001/mês a R$ 40.000/mês     3
# Name: count, dtype: int64

# %%
# Primeiro fazer o filtro das faixas salariais de 30 a 40k por mês
# trocar os outliers pela média
media_30_40=dados[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()
# The code was attempting to calculate the mean of the entire dataframe after filtering.
# The change below specifies that we want the mean of the 'SALARIO' column only.

# %%
#localizar os dados e substituir os outliers pela média gerada
dados.loc[(dados['FAIXA SALARIAL']=='de R$ 30.001/mês a R$ 40.000/mês') & (dados['SALARIO']>limite_superior),'SALARIO'] = media_30_40
#

# %%
dados[dados['SALARIO']>=limite_superior]['FAIXA SALARIAL'].value_counts()
# Out:
# FAIXA SALARIAL
# Acima de R$ 40.001/mês    19
# Name: count, dtype: int64

# %%
media_40=dados[(dados['FAIXA SALARIAL']=='Acima R$ 40.001/mês') & (dados['SALARIO']<limite_superior)]['SALARIO'].mean()
media_40
# Out:
# nan

# %% [markdown]
# ###Intervalo de confiança

# %%
salarios=dados['SALARIO']

# %%
media_amostral= np.mean(salarios)
media_amostral
# Out:
# 10247.43200236234

# %%
desvio_amostral= np.std(salarios)
desvio_amostral
# Out:
# 14370.38041525522

# %%
nivel_confianca= 0.95

# %%
tamanho_amostra= len(salarios)
tamanho_amostra
# Out:
# 4271

# %%
from scipy import stats

# %%
erro_padrao=stats.sem(salarios)
erro_padrao
# Out:
# 219.91473399776862

# %%
intervalo_confianca=stats.t.interval(nivel_confianca, tamanho_amostra-1, loc=media_amostral, scale=erro_padrao)

# %%
intervalo_confianca #95% dos salários ficam entre esses valores
# Out:
# (9816.284832630186, 10678.579172094494)

# %% [markdown]
# #Featuring engineering - criando novas variáveis para facilitar a análise
#
# > Adicionar aspas

# %%
#é o processo de criar novas variáveis a partir dos dados existentes para melhorar a análise e a modelagem
#permite melhores insights e previsões
def preencher_nivel(gestor,nivel):
    if gestor == 1:
        return "Pessoa Gestora"
    else:
        pass
        return nivel

# %%
dados['NOVO_NIVEL']=dados.apply(lambda x: preencher_nivel(x['GESTOR?'],x['NIVEL']), axis=1)

# %%
dados['NOVO_NIVEL'].value_counts()
# Out:
# NOVO_NIVEL
# Pleno             1060
# Júnior            1023
# Sênior             898
# Pessoa Gestora     713
# Name: count, dtype: int64

# %%
dados= pd.get_dummies(dados, columns=['NIVEL'])

# %%
dados.columns # transformamos variaveis discretas em continuas
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior'],
#       dtype='object')

# %%
# nova categoria pra idade -gerações
def determinar_geracao(idade):
    if 39<idade<=58:
      return "Geração X"
    elif 29< idade <= 39:
        return "Millenial"
    elif 13< idade<=29:
          return "Geração Z"
    else:
      return "Outra geração"

# %%
dados['GERACAO']=dados['IDADE'].apply(determinar_geracao)

# %%
dados['GERACAO'].value_counts()
# Out:
# GERACAO
# Geração Z    1999
# Millenial    1761
# Geração X     511
# Name: count, dtype: int64

# %%
dados2= pd.read_excel('/content/drive/MyDrive/Cópia de Planilha_Aula_parte2.xlsx')

# %%
dados2.head()
# Out:
#                                  ID  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96
# 1  zzls2oftfn9law393oezzls2ofhvfpzd
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg
#
#   Quanto tempo de experiência na área de dados você tem?  \
# 0                                      de 1 a 2 anos
# 1                                      de 3 a 4 anos
# 2                                      de 3 a 4 anos
# 3                                      de 4 a 6 anos
# 4             Não tenho experiência na área de dados
#
#   Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?  \
# 0                                     de 7 a 10 anos
# 1                                     Menos de 1 ano
# 2                                    Mais de 10 anos
# 3  Não tive experiência na área de TI/Engenharia ...
# 4                                    Mais de 10 anos
#
# ...

# %%
dados=dados.merge(dados2, on='ID', how='left')

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'UF ONDE MORA',
#        'REGIAO ONDE MORA', 'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM',
#        'NIVEL DE ENSINO', 'ÁREA DE FORMAÇÃO',
#        'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
# ...

# %%
dados['Você pretende mudar de emprego nos próximos 6 meses?'].value_counts()
# Out:
# Você pretende mudar de emprego nos próximos 6 meses?
# Não estou buscando, mas me considero aberto a outras oportunidades         1354
# Estou em busca de oportunidades dentro ou fora do Brasil                   1011
# Não estou buscando e não pretendo mudar de emprego nos próximos 6 meses     978
# Estou em busca de oportunidades, mas apenas fora do Brasil                  353
# Name: count, dtype: int64

# %%
#criar uma coluna com categorias de quem busca e quem nao busca
dados['EM_BUSCA']= dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('em busca', case=False)

# %%
dados['EM_BUSCA'].value_counts()
# Out:
# EM_BUSCA
# False    2332
# True     1364
# Name: count, dtype: int64

# %%
#criar uma coluna com categorias de quem busca e quem nao buscA
dados['ABERTO_OPORTUNIDADES']= dados['Você pretende mudar de emprego nos próximos 6 meses?'].str.contains('aberto', case=False)

# %%
dados['ABERTO_OPORTUNIDADES'].value_counts()
# Out:
# ABERTO_OPORTUNIDADES
# False    2342
# True     1354
# Name: count, dtype: int64

# %%
dados['COR/RACA/ETNIA'].value_counts()
# Out:
# COR/RACA/ETNIA
# Branca                  2746
# Parda                   1054
# Preta                    291
# Amarela                  128
# Prefiro não informar      26
# Outra                     17
# Indígena                  11
# Name: count, dtype: int64

# %%
#criar uma coluna com categorias de quem busca e quem nao buscA
dados['BRANCAS']= dados['COR/RACA/ETNIA'].str.contains('Branca', case=False)

# %%
dados['BRANCAS'].value_counts()
# Out:
# BRANCAS
# True     2746
# False    1527
# Name: count, dtype: int64

# %%
#The first argument should contain all the values you want to check
dados['NAO_BRANCAS']= dados['COR/RACA/ETNIA'].str.contains('Parda|Preta|Amarela|Indígena', case=False)

# %%
dados['NAO_BRANCAS'].value_counts()
# Out:
# NAO_BRANCAS
# False    2789
# True     1484
# Name: count, dtype: int64

# %%
#correlação positiva - 2 variaveis impulsionam juntas estuda mais aprende +; negativa uma aumenta e a outra diminui
#proxima de 1 é positivo e de -1 negativa
#exemplo da negativa - + assisto netflix menor meu desempenho academico

# %% [markdown]
# ###Correlação

# %%
correlacao_continua= dados['IDADE'].corr(dados['SALARIO'])
correlacao_continua
# Out:
# 0.17645997054558626

# %%
from scipy.stats import chi2_contingency

# %%
def cramer_coeficiente(coluna1,coluna2):
  tabela_cruzada= np.array(pd.crosstab(coluna1, coluna2))
  chi2=chi2_contingency(tabela_cruzada)[0]
  soma= np.sum(tabela_cruzada)
  mini= min(tabela_cruzada.shape)-1
  cramer= np.sqrt(chi2/(soma*mini))
  return cramer

# %%
cramer_coeficiente(dados['NIVEL DE ENSINO'], dados['GENERO'])
# Out:
# 0.076119232802818

# %%
tabela_cruzada= pd.crosstab(dados['COR/RACA/ETNIA'], dados['NIVEL DE ENSINO'])
tabela_cruzada
# Out:
# NIVEL DE ENSINO       Doutorado ou Phd  Estudante de Graduação  \
# COR/RACA/ETNIA
# Amarela                              7                      15
# Branca                             127                     365
# Indígena                             0                       2
# Outra                                0                       0
# Parda                               50                     178
# Prefiro não informar                 1                       2
# Preta                                6                      51
#
# NIVEL DE ENSINO       Graduação/Bacharelado  Mestrado  \
# COR/RACA/ETNIA
# Amarela                                  50        14
# Branca                                  999       355
# Indígena                                  4         2
# Outra                                     6         3
# Parda                                   333       113
# Prefiro não informar                     14         1
# ...

# %%
#TABELA CRUA SÓ A MATRIZ
np.array(tabela_cruzada)
# Out:
# array([[  7,  15,  50,  14,   2,   0,  40],
#        [127, 365, 999, 355,  65,   8, 827],
#        [  0,   2,   4,   2,   0,   0,   3],
#        [  0,   0,   6,   3,   1,   0,   7],
#        [ 50, 178, 333, 113,  33,   3, 344],
#        [  1,   2,  14,   1,   0,   1,   7],
#        [  6,  51, 104,  33,   9,   0,  88]])

# %% [markdown]
# ###Conectando SQL com Pandas

# %%
import sqlite3

# %%
conexao=sqlite3.connect('/content/drive/MyDrive/statusbrasil2')

# %%
query="SELECT * FROM Municipios_brasileiros WHERE Cidade='Itaquaquecetuba';"

# %%
query
# Out:
# "SELECT * FROM Municipios_brasileiros WHERE Cidade='Itaquaquecetuba';"

# %%
pd.read_sql(query,con=conexao)
# Out:
#             Cidade Estado   Regiao  municipio_ID
# 0  Itaquaquecetuba     SP  Sudeste          5043

# %%
lista_estados=list(dados['UF ONDE MORA'].unique())

# %%
query='''SELECT Municipios_brasileiros.Estado, AVG(Municipios_status.renda) FROM Municipios_brasileiros
      INNER JOIN Municipios_status ON Municipios_brasileiros.municipio_ID = Municipios_status.municipio_ID
      WHERE Municipios_brasileiros.Estado IN lista_estados
      GROUP BY Municipios_brasileiros.Estado;'''

# %%
print(query)

# %%
## lista de estados usando .format

query='''SELECT Municipios_brasileiros.Estado, AVG(Municipios_status.renda) FROM Municipios_brasileiros
      INNER JOIN Municipios_status ON Municipios_brasileiros.municipio_ID = Municipios_status.municipio_ID
      WHERE Municipios_brasileiros.Estado IN ({})
      GROUP BY Municipios_brasileiros.Estado;'''.format(','.join(['?' for _ in lista_estados]))

# %%
estado_renda= pd.read_sql(query, con=conexao, params=lista_estados)

# %%
dados.rename(columns={'UF ONDE MORA':'Estado'}, inplace=True)

# %%
dados.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'IDADE', 'FAIXA IDADE', 'GENERO', 'COR/RACA/ETNIA',
#        'PCD', 'EXPERIENCIA_PROFISSIONAL_PREJUDICADA', 'ASPECTOS_PREJUDICADOS',
#        'VIVE_NO_BRASIL', 'ESTADO ONDE MORA', 'Estado', 'REGIAO ONDE MORA',
#        'MUDOU DE ESTADO?', 'REGIAO DE ORIGEM', 'NIVEL DE ENSINO',
#        'ÁREA DE FORMAÇÃO', 'QUAL SUA SITUAÇÃO ATUAL DE TRABALHO?', 'SETOR',
#        'NUMERO DE FUNCIONARIOS', 'GESTOR?', 'CARGO COMO GESTOR', 'CARGO ATUAL',
#        'FAIXA SALARIAL',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE DADOS VOCÊ TEM?',
#        'QUANTO TEMPO DE EXPERIÊNCIA NA ÁREA DE TI/ENGENHARIA DE SOFTWARE VOCÊ TEVE ANTES DE COMEÇAR A TRABALHAR NA ÁREA DE DADOS?',
#        'SALARIO', 'NOVO_NIVEL', 'NIVEL_Júnior', 'NIVEL_Pleno', 'NIVEL_Sênior',
#        'GERACAO', 'Quanto tempo de experiência na área de dados você tem?',
#        'Quanto tempo de experiência na área de TI/Engenharia de Software você teve antes de começar a trabalhar na área de dados?',
# ...

# %%
dados.merge(estado_renda, on='Estado', how='left')
# Out:
#       Unnamed: 0                                ID      IDADE FAIXA IDADE  \
# 0              0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.000000       35-39
# 1              1  zzls2oftfn9law393oezzls2ofhvfpzd  32.000000       30-34
# 2              2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.000000       50-54
# 3              3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.000000       25-29
# 4              4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.000000       45-49
# ...          ...                               ...        ...         ...
# 4268        4266  01jnrn9f6va0menfhk2ztm01jnrn96bp  26.000000       25-29
# 4269        4267  01dyfxam4u4bi29fem01dyfxaq9akvqp  30.000000       30-34
# 4270        4268  00zw9ks9d40z4u00zz3d20iix65qpli3  29.000000       25-29
# 4271        4269  00xu7yujd7s57emj00xu7y0c3njix3de  20.205479       17-21
# 4272        4270  00lb35llmdsidpa00lb35qcdysnzvhv7  24.000000       22-24
#
#          GENERO COR/RACA/ETNIA  PCD  \
# 0     Masculino          Parda  Não
# ...

# %%
correlacao_educacao_salario=dados['SALARIO'].corr(dados['NIVEL DE ENSINO'])
correlacao_educacao_salario
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-135-cde4553bc7a7> in <cell line: 1>()
# ----> 1 correlacao_educacao_salario=dados['SALARIO'].corr(dados['NIVEL DE ENSINO'])
#       2 correlacao_educacao_salario
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in corr(self, other, method, min_periods)
#    2858
#    2859         this_values = this.to_numpy(dtype=float, na_value=np.nan, copy=False)
# -> 2860         other_values = other.to_numpy(dtype=float, na_value=np.nan, copy=False)
#    2861
#    2862         if method in ["pearson", "spearman", "kendall"] or callable(method):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in to_numpy(self, dtype, copy, na_value, **kwargs)
#     660             values[np.asanyarray(isna(self))] = na_value
#     661
# --> 662         result = np.asarray(values, dtype=dtype)
#     663
# ...

# %%
# Convert 'NIVEL DE ENSINO' to a numerical representation
# !pip install scikit-learn
import pandas as pd
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
dados['NIVEL DE ENSINO'] = le.fit_transform(dados['NIVEL DE ENSINO'])

# Calculate the correlation
correlacao_educacao_salario = dados['SALARIO'].corr(dados['NIVEL DE ENSINO'])
correlacao_educacao_salario
# Out:
# ...
# 0.09300371748209868

# %% [markdown]
# #Visualização de dados

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
dados= pd.read_csv('/content/drive/MyDrive/grafanalisedados.csv')

# %%
dados.head()
# Out:
#                                  ID IDADE FAIXA IDADE     GENERO  \
# 0  zzqzz3l9ily8nuo2m7wyzzqzz3w48o96  39.0       35-39  Masculino
# 1  zzls2oftfn9law393oezzls2ofhvfpzd  32.0       30-34  Masculino
# 2  zzdwqzfqqp1ypc7ps6m0hzzdwqz292yi  53.0       50-54  Masculino
# 3  zzbqh3uy7yk7k9qmkzzbqtb4s9faqspl  27.0       25-29  Masculino
# 4  zzaf1m95yan929rb94wzzaf1mekhvhpg  46.0       45-49   Feminino
#
#   COR/RACA/ETNIA  PCD               EXPERIENCIA_PROFISSIONAL_PREJUDICADA  \
# 0          Parda  Não  Não acredito que minha experiência profissiona...
# 1          Parda  Não  Sim, acredito que a minha a experiência profis...
# 2         Branca  Não                                                NaN
# 3         Branca  Não                                                NaN
# 4         Branca  Não  Não acredito que minha experiência profissiona...
#
#                           ASPECTOS_PREJUDICADOS  VIVE_NO_BRASIL  \
# 0                                           NaN            True
# ...

# %%
genero_counts=dados['GENERO'].value_counts()
genero_counts
# Out:
# GENERO
# Masculino               3194
# Feminino                1056
# Prefiro não informar      21
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns

# %%
plt.figure()
plt.bar(height= genero_counts.values, x= genero_counts.index)
plt.title('Quantidade de pessoas por gênero na área de dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.show()

# %%
plt.figure()
sns.countplot(data=dados, x='GENERO', palette='pastel')
plt.title('Quantidade de pessoas por gênero na área de dados')
plt.xlabel('Gênero')
plt.ylabel('Contagem')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-143-33a294414f4c>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=dados, x='GENERO', palette='pastel')

# %%
# Convert 'SALARIO' column to numeric type
dados['SALARIO'] = dados['SALARIO'].str.replace('R$', '', regex=False).str.replace('.', '', regex=False).str.replace(',', '.', regex=False)
dados['SALARIO'] = pd.to_numeric(dados['SALARIO'])
salario_por_idade = dados.groupby('IDADE')['SALARIO'].mean()
salario_por_idade
# Out:
# IDADE
# 18.0                       4230.307692
# 19.0                       4519.590909
# 20.0                       5004.272727
# 20.205.479.452.054.700     3536.000000
# 21.0                       4578.737179
# 22.0                       4394.689815
# 23.0                       5602.406897
# 24.0                       6151.622449
# 25.0                       7616.392336
# 26.0                       7700.071174
# 27.0                       8237.429766
# 28.0                       9737.938144
# 29.0                       9554.853162
# 30.0                      10316.412702
# 31.0                      10021.462609
# 31.153.517.220.250.300     9646.330882
# 32.0                      10843.197778
# 33.0                      11592.718611
# 34.0                      12294.640212
# 35.0                      12435.845103
# 36.0                      12267.966558
# 37.0                      12613.528390
# 38.0                      13802.724872
# 39.0                      13309.083010
# ...

# %%
plt.figure()
plt.plot(salario_por_idade.index, salario_por_idade.values, marker='o', linestyle='--')
plt.title('Salário médio por idade')
plt.xlabel('Idade')
plt.grid(True)
plt.ylabel('Salário médio')
plt.show()
#

# %%
import plotly.express as px

# %%
fig=px.line(salario_por_idade.reset_index(), x='IDADE', y='SALARIO', title='Salário médio por idade', markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(15,6))
plt.scatter(dados['IDADE'], dados['SALARIO'], alpha= 0.5)
plt.title('Dispersão do salário médio por idade')
plt.xlabel('Idade')
plt.grid(True)
plt.ylabel('Salário médio')
plt.show()

# %%
# Convert 'IDADE' column to numeric, handling errors
dados_filtered['IDADE'] = pd.to_numeric(dados_filtered['IDADE'], errors='coerce')

# Remove rows with NaN values in 'IDADE'
dados_filtered = dados_filtered.dropna(subset=['IDADE'])

# Now you should be able to create the scatter plot
fig = px.scatter(dados_filtered, x='IDADE', y='SALARIO', title='Dispersão do salário médio por idade', trendline='ols')
fig.show()
# Out:
# <ipython-input-155-9501b74a1c98>:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
